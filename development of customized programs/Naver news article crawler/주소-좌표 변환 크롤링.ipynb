# %%
import requests

# %%
defaultURL = "https://dapi.kakao.com/v2/local/search/keyword"
headers = {'Content-Type': 'application/json; charset=utf-8',
                'Authorization': 'KakaoAK 8e0e3db91e6957e61929511be2e3787d'} #개인별 부여}
oneResOutput = 15
parameters = {'sort':'accuracy', 'page':1, 'size':oneResOutput, 'query':""} #size : the num of result for each page!

# %%
defaultURL = "https://dapi.kakao.com/v2/local/search/address"
headers = {'Content-Type': 'application/json; charset=utf-8',
                'Authorization': 'KakaoAK 8e0e3db91e6957e61929511be2e3787d'} #개인별 부여}
parameters = {'query':""} #size : the num of result for each page!

# %%
parameters['query'] = "홍은동 두산위브"

# %%
res = requests.get(defaultURL, headers = headers, params = parameters)

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'documents': [{'address_name': '서울 서대문구 홍은동 19-19',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '부동산 > 주거시설 > 아파트',
#    'distance': '',
#    'id': '1649893660',
#    'phone': '',
#    'place_name': '북한산두산위브1차아파트',
#    'place_url': 'http://place.map.kakao.com/1649893660',
#    'road_address_name': '서울 서대문구 홍은중앙로3길 9',
#    'x': '126.94555764535824',
#    'y': '37.597859110420224'},
#   {'address_name': '서울 서대문구 홍은동 13-25',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '부동산 > 주거시설 > 아파트',
#    'distance': '',
#    'id': '599022135',
#    'phone': '',
#    'place_name': '북한산두산위브2차아파트(2020년11월예정)',
#    'place_url': 'http://place.map.kakao.com/599022135',
#    'road_address_name': '서울 서대문구 홍은중앙로3길 65-13',
#    'x': '126.944849031793',
#    'y': '37.5996634662223'},
#   {'address_name': '서울 서대문구 홍은동 456',
#    'category_group_code': 'AG2',
#    'category_group_name': '중개업소',
#    'category_name': '부동산 > 부동산서비스 > 부동산중개업소',
#    'distance': '',
#    'id': '12601840',
#    'phone': '02-379-4989',
#    'place_name': '두산위브 공인중개사사무소',
#    'place_url': 'http://place.map.kakao.com/12601840',
#    'road_address_name': '서울 서대문구 모래내로 309',
#    'x': '126.931318551037',
#    'y': '37.5788020001006'},
#   {'address_name': '서울 서대문구 홍은동 11-494',
#    'category_group_code': 'AG2',
#    'category_group_name': '중개업소',
#    'category_name': '부동산 > 부동산서비스 > 부동산중개업소',
#    'distance': '',
#    'id': '202984321',
#    'phone': '02-396-9388',
#    'place_name': '두산위브공인중개사사무소',
#    'place_url': 'http://place.map.kakao.com/202984321',
#    'road_address_name': '서울 서대문구 홍은중앙로 75-8',
#    'x': '126.946222123259',
#    'y': '37.5981738609235'},
#   {'address_name': '서울 서대문구 홍은동 19-19',
#    'category_group_code': 'AG2',
#    'category_group_name': '중개업소',
#    'category_name': '부동산 > 부동산서비스 > 부동산중개업소',
#    'distance': '',
#    'id': '1747506717',
#    'phone': '02-395-6600',
#    'place_name': '스마트공인중개사',
#    'place_url': 'http://place.map.kakao.com/1747506717',
#    'road_address_name': '서울 서대문구 홍은중앙로3길 9',
#    'x': '126.945668394065',
#    'y': '37.5981673003849'}],
#  'meta': {'is_end': True,
#   'pageable_count': 5,
#   'same_name': {'keyword': '두산위브',
#    'region': [],
#    'selected_region': '서울 서대문구 홍은동'},
#   'total_count': 13}}

# %%
for place in res.json()['documents'] : 
    print("\t".join([place['place_name'], place['address_name'], place['x'], place['y'], place['place_url']]))
# Out:
# 북한산두산위브아파트	서울 서대문구 홍은동 19-19	126.94569443880033	37.59816731237129	http://place.map.daum.net/1649893660
# 두산위브 공인중개사사무소	서울 서대문구 홍은동 456	126.931318551037	37.5788020001006	http://place.map.daum.net/12601840
# 북한산두산위브2차	서울 서대문구 홍은동 산 1-58	126.944849031793	37.5996634662223	http://place.map.daum.net/599022135
# 두산위브공인중개사사무소	서울 서대문구 홍은동 11-494	126.946222123259	37.5981738609235	http://place.map.daum.net/202984321

# %%
import pandas as pd

# %%
apartments = pd.read_excel('아파트목록.xlsx')

# %%
apartments
# Out:
#                  검색어   x   y  주소
# 0           경희궁 롯데캐슬 NaN NaN NaN
# 1            종로 센트레빌 NaN NaN NaN
# 2        종로 청계 힐스테이트 NaN NaN NaN
# 3         서울역 센트럴 자이 NaN NaN NaN
# 4         신당 KCC 스위첸 NaN NaN NaN
# 5        서울역한라비발디센트럴 NaN NaN NaN
# 6          신당래미안하이베르 NaN NaN NaN
# 7           청구 e편한세상 NaN NaN NaN
# 8         용산 롯데캐슬 포레 NaN NaN NaN
# 9          용산 E편한 세상 NaN NaN NaN
# 10          용산 브라운스톤 NaN NaN NaN
# 11      효창파크 kcc 스위첸 NaN NaN NaN
# 12         e편한세상 신금호 NaN NaN NaN
# 13          신금호 파크자이 NaN NaN NaN
# 14         행당서울숲푸르지오 NaN NaN NaN
# 15       서울숲 푸르지오 1차 NaN NaN NaN
# 16       서울숲 푸르지오 2차 NaN NaN NaN
# 17           금호자이 1차 NaN NaN NaN
# 18          래미안 하이리버 NaN NaN NaN
# 19          금호 자이 2차 NaN NaN NaN
# 20    힐스테이트서울숲리버아파트  NaN NaN NaN
# 21             대성유니드 NaN NaN NaN
# 22          래미안옥수리버젠 NaN NaN NaN
# 23       e편한세상옥수파크힐스 NaN NaN NaN
# 24             왕십리자이 NaN NaN NaN
# 25           행당 두산위브 NaN NaN NaN
# 26      서울숲리버뷰자이아파트  NaN NaN NaN
# 27         답십리 파크 자이 NaN NaN NaN
# 28            전농 아름숲 NaN NaN NaN
# 29          래미안 허브리츠 NaN NaN NaN
# ..               ...  ..  ..  ..
# 83           돈의문센트레빌 NaN NaN NaN
# 84            홍은센트레빌 NaN NaN NaN
# 85            북한산 더샵 NaN NaN NaN
# 86          신촌 그랑 자이 NaN NaN NaN
# 87             공덕 자이 NaN NaN NaN
# 88            마포자이2차 NaN NaN NaN
# 89      래미안밤섬리베뉴I아파트 NaN NaN NaN
# 90         래미안밤섬리베뉴2 NaN NaN NaN
# 91        공덕브라운스톤아파트 NaN NaN NaN
# 92        신공덕아이파크아파트 NaN NaN NaN
# 93         래미안마포웰스트림 NaN NaN NaN
# 94       래미안마포리버웰아파트 NaN NaN NaN
# 95       마포e편한세상리버파크 NaN NaN NaN
# 96            아현아이파크 NaN NaN NaN
# 97           목동힐스테이트 NaN NaN NaN
# 98          고척파크푸르지오 NaN NaN NaN
# 99          벽산베스트블루밍 NaN NaN NaN
# 100           한신휴플러스 NaN NaN NaN
# 101       구로동 구로두산위브 NaN NaN NaN
# 102     당산신동아파밀리에아파트 NaN NaN NaN
# 103   당산롯데캐슬프레스티지아파트 NaN NaN NaN
# 104       영등포 자이 아파트 NaN NaN NaN
# 105          신길자이아파트 NaN NaN NaN
# 106          래미안트윈파크 NaN NaN NaN
# 107            사당유니드 NaN NaN NaN
# 108          상도 파크자이 NaN NaN NaN
# 109  e편한 세상 서울대입구 2차 NaN NaN NaN
# 110     e편한 세상 서울대입구 NaN NaN NaN
# 111       관악브라운스톤아파트 NaN NaN NaN
# 112         녹천 두산 위브 NaN NaN NaN
#
# [113 rows x 4 columns]

# %%
searchSession = requests.Session()

# %%
res = searchSession.get(defaultURL, headers=headers, params=parameters)

# %%
res.json()['documents'][0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-187c442b8d7a> in <module>
# ----> 1 res.json()['documents'][0]
#
# AttributeError: 'list' object has no attribute 'json'

# %%
for apart in apartments.iterrows():
    parameters['query'] = apart[1].검색어
    tempRes = searchSession.get(defaultURL, headers=headers, params = parameters)
    try : 
        firstItem = tempRes.json()['documents'][0]
    except IndexError : 
        print(apart[1].검색어)
        continue
    else:
        apartments.loc[apart[0], 'x'] = firstItem['x']
        apartments.loc[apart[0], 'y'] = firstItem['y']
        apartments.loc[apart[0], '검색 주소'] = firstItem['address_name']

# %%
apartments.to_excel('검색결과.xlsx')

# %%
districts = """기배동
남양읍
동탄1동
동탄2동
동탄3동
동탄4동
동탄5동
동탄6동
마도면
매송면
반월동
병점1동
병점2동
봉담읍
비봉면
서신면
송산면
양감면
우정읍
장안면
정남면
진안동
팔탄면
향남읍
화산동
"""

# %%
districts = districts.split()

# %%
districts
# Out:
# ['기배동',
#  '남양읍',
#  '동탄1동',
#  '동탄2동',
#  '동탄3동',
#  '동탄4동',
#  '동탄5동',
#  '동탄6동',
#  '마도면',
#  '매송면',
#  '반월동',
#  '병점1동',
#  '병점2동',
#  '봉담읍',
#  '비봉면',
#  '서신면',
#  '송산면',
#  '양감면',
#  '우정읍',
#  '장안면',
#  '정남면',
#  '진안동',
#  '팔탄면',
#  '향남읍',
#  '화산동']

# %%
res = []

for d in districts : 
    each = [d]
    parameters['query'] = "화성시 " + d
    tempRes = searchSession.get(defaultURL, headers=headers, params = parameters)
    try : 
        firstItem = tempRes.json()['documents'][0]
    except IndexError : 
        print(apart[1].검색어)
        count =0
        while count < 3 : 
            each.append("")
            count += 1
        continue
    else:
        each.append(firstItem['x'])
        each.append(firstItem['y'])
        each.append(firstItem['address_name'])
    res.append(each)

# %%
res
# Out:
# [['기배동', '126.98468046200632', '37.22439891156655', '경기 화성시 기배동'],
#  ['남양읍', '126.82377585283497', '37.21178748486248', '경기 화성시 남양읍'],
#  ['동탄1동', '127.07191589549852', '37.20652287428139', '경기 화성시 동탄1동'],
#  ['동탄2동', '127.07239331174148', '37.19685610320312', '경기 화성시 동탄2동'],
#  ['동탄3동', '127.05889613721526', '37.209874762598965', '경기 화성시 동탄3동'],
#  ['동탄4동', '127.11230669096592', '37.19972998091538', '경기 화성시 동탄4동'],
#  ['동탄5동', '127.10399013687194', '37.21015732420902', '경기 화성시 동탄5동'],
#  ['동탄6동', '127.08961242071207', '37.173424136938294', '경기 화성시 동탄6동'],
#  ['마도면', '126.76963365694209', '37.20547372395443', '경기 화성시 마도면'],
#  ['매송면', '126.90911741910271', '37.25234070312284', '경기 화성시 매송면'],
#  ['반월동', '127.06059550834166', '37.233074102838565', '경기 화성시 반월동'],
#  ['병점1동', '127.03726938856923', '37.20691007415054', '경기 화성시 병점1동'],
#  ['병점2동', '127.04302167810036', '37.211478252670176', '경기 화성시 병점2동'],
#  ['봉담읍', '126.94954170792754', '37.22006772571997', '경기 화성시 봉담읍'],
#  ['비봉면', '126.87340990534625', '37.23517725101547', '경기 화성시 비봉면'],
#  ['서신면', '126.70873219077568', '37.166572821895606', '경기 화성시 서신면'],
#  ['송산면', '126.73918496575735', '37.21786307648641', '경기 화성시 송산면'],
#  ['양감면', '126.94442445684989', '37.08130590206357', '경기 화성시 양감면'],
#  ['우정읍', '126.81535291775133', '37.08982183980982', '경기 화성시 우정읍'],
#  ['장안면', '126.83132895709633', '37.079764484507706', '경기 화성시 장안면'],
#  ['정남면', '126.97133684497753', '37.159985554685846', '경기 화성시 정남면'],
#  ['진안동', '127.03496075268005', '37.213322652245516', '경기 화성시 진안동'],
#  ['팔탄면', '126.90485259192768', '37.162264742482655', '경기 화성시 팔탄면'],
#  ['향남읍', '126.92035298366046', '37.13243667974891', '경기 화성시 향남읍'],
#  ['화산동', '127.01481568914625', '37.206176148674935', '경기 화성시 화산동']]

# %%
dongs = pd.DataFrame(res, columns = ['동명', 'x', 'y', '주소'])

# %%
dongs.to_csv("화성시 행정동 위치.csv")
