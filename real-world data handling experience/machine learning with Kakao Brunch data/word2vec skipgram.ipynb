# %%
# word2vec model - skipgram
#---------------------------------------
#
# In this example, we will download and preprocess the movie
#  review data.
#
# From this data set we will compute/fit a Doc2Vec model to get
# Document vectors.  From these document vectors, we will split the
# documents into train/test and use these doc vectors to do sentiment
# analysis on the movie review dataset.

import tensorflow as tf
import numpy as np
import os
import pickle
import text_helpers_new as text_helpers

# %%
with open("data0Collect.pkl", 'rb') as f:
    data0Collect = pickle.load(f)

# %%
texts = list(data0Collect.values())

# %%
texts[:3]

# %%
from tensorflow.python.framework import ops
ops.reset_default_graph()

# ============ settings for global variables =====================
# Make a saving directory if it doesn't exist
data_folder_name = 'temp3'
if not os.path.exists(data_folder_name):
    os.makedirs(data_folder_name)

# Declare model parameters
batch_size = 200
vocabulary_size = 10000
generations = 100000
model_learning_rate = 0.01

embedding_size = 200   # Word embedding size
# doc_embedding_size = 500   # Document embedding size
# concatenated_size = embedding_size + doc_embedding_size

targetEpochs = 1

num_sampled = int(batch_size/2)    # Number of negative examples to sample.
window_size = 2       # How many words to consider to the left.

# Add checkpoints to training
save_embeddings_every = 5000
print_valid_every = 5000
print_loss_every = 1000

# We pick a few test words for validation.
# sample_words = ['love', 'hate', 'happy', 'sad', 'man', 'woman']
# Later we will have to transform these into indices


# Texts must contain at least 3 words
# with open('.pkl', 'rb') as f:
#     texts = pickle.load(f)

texts = [x for x in texts  if len(x) > window_size ]

# Start a graph session
sess = tf.Session()

# %%
# Build our data set and dictionaries
print('Creating Dictionary')
word_dictionary = text_helpers.build_dictionary(texts, vocabulary_size, sentenceSplited=True)
word_dictionary_rev = dict(zip(word_dictionary.values(), word_dictionary.keys()))
text_data = text_helpers.text_to_numbers(texts, word_dictionary, sentenceSplited=True)
text_data_indices = list(range(len(text_data)))

numSet = np.random.choice(list(word_dictionary_rev.keys()), 4)
sample_words = [word_dictionary_rev[x] for x in numSet]

# Get validation word keys
indexOf_sample_words = [word_dictionary[x] for x in sample_words]

print('Creating Model')
# Define Embeddings:
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
# doc_embeddings = tf.Variable(tf.random_uniform([len(texts), doc_embedding_size], -1.0, 1.0))

# NCE loss parameters
nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                               stddev=1.0 / np.sqrt(embedding_size)))
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# Create data/target placeholders
x_inputs = tf.placeholder(tf.int32, shape=[batch_size]) # plus 1 for doc index
y_target = tf.placeholder(tf.int32, shape=[batch_size, 1])
tf_indexOf_sample_words = tf.constant(indexOf_sample_words, dtype=tf.int32)

# Lookup the word embedding
# Add together element embeddings in window:
embed = tf.nn.embedding_lookup(embeddings, x_inputs)

# doc_indices = tf.slice(x_inputs, [0,window_size],[batch_size,1])
# doc_embed = tf.nn.embedding_lookup(doc_embeddings, doc_indices)

# concatenate embeddings
# final_embed = tf.concat(axis=1, values=[(1/window_size)*embed, tf.squeeze(doc_embed)])

# Get loss from prediction
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                     biases=nce_biases,
                                     labels=y_target,
                                     inputs=embed,
                                     num_sampled=num_sampled,
                                     num_classes=vocabulary_size))
                                     
# Create optimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate=model_learning_rate)
train_step = optimizer.minimize(loss)

# Cosine similarity between words
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
sample_word_embeddings = tf.nn.embedding_lookup(normalized_embeddings, tf_indexOf_sample_words)
similarity = tf.matmul(sample_word_embeddings, normalized_embeddings, transpose_b=True)

# Create model saving operation
# saver = tf.train.Saver({"embeddings": embeddings, "doc_embeddings": doc_embeddings})
saver = tf.train.Saver({"embeddings": embeddings})

#Add variable initializer.
init = tf.global_variables_initializer()
sess.run(init)

# %%
# Run the doc2vec model.
print('Starting Training')
loss_vec = []
loss_x_vec = []

currentEpoch = 0
currentIndexPosition = -1
np.random.shuffle(text_data_indices)
previousBatch = []
previousLabel = []
method = 'skip_gram'
generation = 0

# while (currentEpoch < targetEpochs) and (generation < generations):
while (currentEpoch < targetEpochs):
    batch_inputs, batch_labels, previousBatch, previousLabel, currentIndexPosition, epochUp =\
        text_helpers.generate_batch_data(previousBatch, previousLabel, currentIndexPosition, text_data_indices, text_data, 
                                         batch_size, window_size, method)
    feed_dict = {x_inputs : batch_inputs, y_target : batch_labels}

    # Run the train step
    sess.run(train_step, feed_dict=feed_dict)

    generation += 1
    currentEpoch += epochUp

    # Return the loss
    if generation % print_loss_every == 0:
        loss_val = sess.run(loss, feed_dict=feed_dict)
        loss_vec.append(loss_val)
        loss_x_vec.append(generation)
        print('Loss at step {} : {} / current epochs : {} / current sentence : {}'\
              .format(generation, loss_val, currentEpoch, currentIndexPosition))
      
    # Validation: Print some random words and top 5 related words
    if generation % print_valid_every == 0:
        sim = sess.run(similarity, feed_dict=feed_dict)
        for j in range(len(sample_words)):
            valid_word = word_dictionary_rev[indexOf_sample_words[j]]
            top_k = 5 # number of nearest neighbors
            nearest = (-sim[j, :]).argsort()[1:top_k+1]
            log_str = "Nearest to {}:".format(valid_word)
            for k in range(top_k):
                close_word = word_dictionary_rev[nearest[k]]
                log_str = '{} {},'.format(log_str, close_word)
            print(log_str)
            
    # Save dictionary + embeddings
    if generation % save_embeddings_every == 0:
        # Save vocabulary dictionary
        with open(os.path.join(data_folder_name,'data0analyzed.pkl'), 'wb') as f:
            pickle.dump(word_dictionary, f)
        
        # Save embeddings
        model_checkpoint_path = os.path.join(os.getcwd(), data_folder_name, 'word2vec_embeddings.ckpt')
        save_path = saver.save(sess, model_checkpoint_path)
        print('Model saved in file: {}'.format(save_path))
# Out:
# Creating Dictionary
# Creating Model
# Starting Training
# Loss at step 1000 : 272.0592956542969 / current epochs : 0 / current sentence : 108
# Loss at step 2000 : 242.02508544921875 / current epochs : 0 / current sentence : 230
# Loss at step 3000 : 221.26219177246094 / current epochs : 0 / current sentence : 334
# Loss at step 4000 : 201.0927276611328 / current epochs : 0 / current sentence : 458
# Loss at step 5000 : 182.1846160888672 / current epochs : 0 / current sentence : 585
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 3292/NNP, 4127/NNG, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 17798/NNG, 4883/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 2740/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 10961/VV,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 6000 : 183.94854736328125 / current epochs : 0 / current sentence : 711
# Loss at step 7000 : 175.04400634765625 / current epochs : 0 / current sentence : 841
# Loss at step 8000 : 163.82937622070312 / current epochs : 0 / current sentence : 958
# Loss at step 9000 : 125.89440155029297 / current epochs : 0 / current sentence : 1089
# Loss at step 10000 : 156.30203247070312 / current epochs : 0 / current sentence : 1193
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 3292/NNP, 4127/NNG, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 17798/NNG, 4883/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 2740/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 10961/VV,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 11000 : 124.06773376464844 / current epochs : 0 / current sentence : 1307
# Loss at step 12000 : 130.18002319335938 / current epochs : 0 / current sentence : 1423
# Loss at step 13000 : 79.36278533935547 / current epochs : 0 / current sentence : 1506
# Loss at step 14000 : 105.41605377197266 / current epochs : 0 / current sentence : 1607
# Loss at step 15000 : 84.44904327392578 / current epochs : 0 / current sentence : 1720
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 3292/NNP, 4127/NNG, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG,
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 2084/VV,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 201000 : 7.385295867919922 / current epochs : 0 / current sentence : 23530
# Loss at step 202000 : 10.208627700805664 / current epochs : 0 / current sentence : 23640
# Loss at step 203000 : 6.877885341644287 / current epochs : 0 / current sentence : 23704
# Loss at step 204000 : 8.087861061096191 / current epochs : 0 / current sentence : 23829
# Loss at step 205000 : 7.030086040496826 / current epochs : 0 / current sentence : 23963
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 2084/VV,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 206000 : 9.336774826049805 / current epochs : 0 / current sentence : 24085
# Loss at step 207000 : 6.736674785614014 / current epochs : 0 / current sentence : 24204
# Loss at step 208000 : 8.40062427520752 / current epochs : 0 / current sentence : 24291
# Loss at step 209000 : 6.978362560272217 / current epochs : 0 / current sentence : 24413
# Loss at step 210000 : 8.50743579864502 / current epochs : 0 / current sentence : 24536
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 2084/VV,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 211000 : 7.9731221199035645 / current epochs : 0 / current sentence : 24653
# Loss at step 212000 : 11.844829559326172 / current epochs : 0 / current sentence : 24748
# Loss at step 213000 : 8.164956092834473 / current epochs : 0 / current sentence : 24862
# Loss at step 214000 : 7.865765571594238 / current epochs : 0 / current sentence : 24972
# Loss at step 215000 : 7.070885181427002 / current epochs : 0 / current sentence : 25075
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 216000 : 6.776515007019043 / current epochs : 0 / current sentence : 25195
# Loss at step 217000 : 6.530062198638916 / current epochs : 0 / current sentence : 25306
# Loss at step 218000 : 6.511025428771973 / current epochs : 0 / current sentence : 25426
# Loss at step 219000 : 6.974463939666748 / current epochs : 0 / current sentence : 25542
# Loss at step 220000 : 7.353188991546631 / current epochs : 0 / current sentence : 25660
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 221000 : 5.864943981170654 / current epochs : 0 / current sentence : 25776
# Loss at step 222000 : 6.886935234069824 / current epochs : 0 / current sentence : 25883
# Loss at step 223000 : 7.684077262878418 / current epochs : 0 / current sentence : 25998
# Loss at step 224000 : 7.145833969116211 / current epochs : 0 / current sentence : 26128
# Loss at step 225000 : 7.464980602264404 / current epochs : 0 / current sentence : 26249
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 226000 : 6.888441562652588 / current epochs : 0 / current sentence : 26382
# Loss at step 227000 : 5.437469482421875 / current epochs : 0 / current sentence : 26500
# Loss at step 228000 : 7.617896556854248 / current epochs : 0 / current sentence : 26628
# Loss at step 229000 : 6.880270481109619 / current epochs : 0 / current sentence : 26752
# Loss at step 230000 : 6.280088901519775 / current epochs : 0 / current sentence : 26873
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 367/NNG, 2653/XR, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 231000 : 6.320026874542236 / current epochs : 0 / current sentence : 26995
# Loss at step 232000 : 7.2680768966674805 / current epochs : 0 / current sentence : 27120
# Loss at step 233000 : 7.410971641540527 / current epochs : 0 / current sentence : 27211
# Loss at step 234000 : 5.724291801452637 / current epochs : 0 / current sentence : 27327
# Loss at step 235000 : 8.275113105773926 / current epochs : 0 / current sentence : 27432
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 11190/NNG, 3292/NNP,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 3023/NNG, 9179/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1332/NNG, 1408/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 19067/NNG, 5253/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 276000 : 6.806634426116943 / current epochs : 0 / current sentence : 32240
# Loss at step 277000 : 6.011955738067627 / current epochs : 0 / current sentence : 32353
# Loss at step 278000 : 6.76460075378418 / current epochs : 0 / current sentence : 32457
# Loss at step 279000 : 7.576164722442627 / current epochs : 0 / current sentence : 32588
# Loss at step 280000 : 7.26158332824707 / current epochs : 0 / current sentence : 32705
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 281000 : 7.954227447509766 / current epochs : 0 / current sentence : 32830
# Loss at step 282000 : 5.981935977935791 / current epochs : 0 / current sentence : 32942
# Loss at step 283000 : 6.80312967300415 / current epochs : 0 / current sentence : 33066
# Loss at step 284000 : 7.603328704833984 / current epochs : 0 / current sentence : 33178
# Loss at step 285000 : 6.412085056304932 / current epochs : 0 / current sentence : 33300
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 286000 : 6.323763847351074 / current epochs : 0 / current sentence : 33413
# Loss at step 287000 : 6.7350850105285645 / current epochs : 0 / current sentence : 33520
# Loss at step 288000 : 5.778730392456055 / current epochs : 0 / current sentence : 33630
# Loss at step 289000 : 6.371480941772461 / current epochs : 0 / current sentence : 33738
# Loss at step 290000 : 6.106412410736084 / current epochs : 0 / current sentence : 33867
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 291000 : 5.839918613433838 / current epochs : 0 / current sentence : 33972
# Loss at step 292000 : 6.387690544128418 / current epochs : 0 / current sentence : 34106
# Loss at step 293000 : 6.911716461181641 / current epochs : 0 / current sentence : 34227
# Loss at step 294000 : 5.811397552490234 / current epochs : 0 / current sentence : 34333
# Loss at step 295000 : 6.410701751708984 / current epochs : 0 / current sentence : 34444
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 296000 : 5.793612003326416 / current epochs : 0 / current sentence : 34571
# Loss at step 297000 : 7.357166767120361 / current epochs : 0 / current sentence : 34684
# Loss at step 298000 : 5.941594123840332 / current epochs : 0 / current sentence : 34810
# Loss at step 299000 : 5.824357986450195 / current epochs : 0 / current sentence : 34937
# Loss at step 300000 : 6.662971019744873 / current epochs : 0 / current sentence : 35048
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 301000 : 6.272130966186523 / current epochs : 0 / current sentence : 35190
# Loss at step 302000 : 6.521944522857666 / current epochs : 0 / current sentence : 35307
# Loss at step 303000 : 5.742910861968994 / current epochs : 0 / current sentence : 35417
# Loss at step 304000 : 5.925031661987305 / current epochs : 0 / current sentence : 35543
# Loss at step 305000 : 6.5088396072387695 / current epochs : 0 / current sentence : 35678
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 3023/NNG,
# Nearest to 1400/NNG: 7349/NNG, 4847/NNG, 1705/VV, 1408/NNG, 1332/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# ...
# Loss at step 736000 : 5.450190544128418 / current epochs : 0 / current sentence : 86231
# Loss at step 737000 : 5.404540538787842 / current epochs : 0 / current sentence : 86346
# Loss at step 738000 : 5.224179744720459 / current epochs : 0 / current sentence : 86466
# Loss at step 739000 : 5.449301719665527 / current epochs : 0 / current sentence : 86588
# Loss at step 740000 : 5.3905348777771 / current epochs : 0 / current sentence : 86701
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 10513/MM,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 741000 : 5.509417533874512 / current epochs : 0 / current sentence : 86809
# Loss at step 742000 : 5.618802547454834 / current epochs : 0 / current sentence : 86931
# Loss at step 743000 : 5.682900428771973 / current epochs : 0 / current sentence : 87043
# Loss at step 744000 : 5.588076114654541 / current epochs : 0 / current sentence : 87159
# Loss at step 745000 : 5.412570953369141 / current epochs : 0 / current sentence : 87250
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 10513/MM,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 746000 : 5.2733612060546875 / current epochs : 0 / current sentence : 87362
# Loss at step 747000 : 5.463494300842285 / current epochs : 0 / current sentence : 87476
# Loss at step 748000 : 5.479101657867432 / current epochs : 0 / current sentence : 87594
# Loss at step 749000 : 5.678563117980957 / current epochs : 0 / current sentence : 87711
# Loss at step 750000 : 5.312680721282959 / current epochs : 0 / current sentence : 87828
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 10513/MM,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 751000 : 5.470144271850586 / current epochs : 0 / current sentence : 87958
# Loss at step 752000 : 5.593630313873291 / current epochs : 0 / current sentence : 88070
# Loss at step 753000 : 5.44813346862793 / current epochs : 0 / current sentence : 88185
# Loss at step 754000 : 5.487341403961182 / current epochs : 0 / current sentence : 88321
# Loss at step 755000 : 5.199583530426025 / current epochs : 0 / current sentence : 88426
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 9179/NNG, 10513/MM,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 756000 : 5.581440448760986 / current epochs : 0 / current sentence : 88530
# Loss at step 757000 : 5.384854793548584 / current epochs : 0 / current sentence : 88618
# Loss at step 758000 : 4.835190296173096 / current epochs : 0 / current sentence : 88726
# Loss at step 759000 : 5.545536994934082 / current epochs : 0 / current sentence : 88850
# Loss at step 760000 : 5.383333206176758 / current epochs : 0 / current sentence : 88962
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 761000 : 5.526384353637695 / current epochs : 0 / current sentence : 89091
# Loss at step 762000 : 5.161664962768555 / current epochs : 0 / current sentence : 89164
# Loss at step 763000 : 5.267011642456055 / current epochs : 0 / current sentence : 89291
# Loss at step 764000 : 5.468403339385986 / current epochs : 0 / current sentence : 89412
# Loss at step 765000 : 5.584975719451904 / current epochs : 0 / current sentence : 89545
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 766000 : 5.179432392120361 / current epochs : 0 / current sentence : 89638
# Loss at step 767000 : 5.376688003540039 / current epochs : 0 / current sentence : 89731
# Loss at step 768000 : 5.409804821014404 / current epochs : 0 / current sentence : 89855
# Loss at step 769000 : 5.475346088409424 / current epochs : 0 / current sentence : 89969
# Loss at step 770000 : 5.640904426574707 / current epochs : 0 / current sentence : 90089
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 771000 : 5.447393894195557 / current epochs : 0 / current sentence : 90205
# Loss at step 772000 : 5.64678955078125 / current epochs : 0 / current sentence : 90313
# Loss at step 773000 : 5.640781402587891 / current epochs : 0 / current sentence : 90427
# Loss at step 774000 : 5.568670749664307 / current epochs : 0 / current sentence : 90533
# Loss at step 775000 : 5.462331771850586 / current epochs : 0 / current sentence : 90640
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 776000 : 5.289638519287109 / current epochs : 0 / current sentence : 90749
# Loss at step 777000 : 5.688469409942627 / current epochs : 0 / current sentence : 90860
# Loss at step 778000 : 5.446555137634277 / current epochs : 0 / current sentence : 90982
# Loss at step 779000 : 5.53999137878418 / current epochs : 0 / current sentence : 91089
# Loss at step 780000 : 5.567394256591797 / current epochs : 0 / current sentence : 91209
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 781000 : 5.354493618011475 / current epochs : 0 / current sentence : 91321
# Loss at step 782000 : 5.682388782501221 / current epochs : 0 / current sentence : 91432
# Loss at step 783000 : 5.441342830657959 / current epochs : 0 / current sentence : 91537
# Loss at step 784000 : 5.428563117980957 / current epochs : 0 / current sentence : 91660
# Loss at step 785000 : 5.531491756439209 / current epochs : 0 / current sentence : 91796
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 786000 : 5.663321018218994 / current epochs : 0 / current sentence : 91929
# Loss at step 787000 : 5.1120991706848145 / current epochs : 0 / current sentence : 92049
# Loss at step 788000 : 5.23090934753418 / current epochs : 0 / current sentence : 92181
# Loss at step 789000 : 5.167047023773193 / current epochs : 0 / current sentence : 92293
# Loss at step 790000 : 5.622321605682373 / current epochs : 0 / current sentence : 92401
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 791000 : 5.570853233337402 / current epochs : 0 / current sentence : 92511
# Loss at step 792000 : 5.232716083526611 / current epochs : 0 / current sentence : 92632
# Loss at step 793000 : 5.69318962097168 / current epochs : 0 / current sentence : 92753
# Loss at step 794000 : 5.3804802894592285 / current epochs : 0 / current sentence : 92868
# Loss at step 795000 : 5.494643688201904 / current epochs : 0 / current sentence : 92973
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 796000 : 5.017559051513672 / current epochs : 0 / current sentence : 93064
# Loss at step 797000 : 5.551601409912109 / current epochs : 0 / current sentence : 93178
# Loss at step 798000 : 4.750647068023682 / current epochs : 0 / current sentence : 93320
# Loss at step 799000 : 5.3188066482543945 / current epochs : 0 / current sentence : 93428
# Loss at step 800000 : 5.641567230224609 / current epochs : 0 / current sentence : 93554
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 801000 : 5.736924648284912 / current epochs : 0 / current sentence : 93668
# Loss at step 802000 : 5.380351543426514 / current epochs : 0 / current sentence : 93771
# Loss at step 803000 : 5.394848823547363 / current epochs : 0 / current sentence : 93902
# Loss at step 804000 : 5.248929500579834 / current epochs : 0 / current sentence : 94032
# Loss at step 805000 : 5.437602519989014 / current epochs : 0 / current sentence : 94166
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 806000 : 5.038360595703125 / current epochs : 0 / current sentence : 94284
# Loss at step 807000 : 5.441826343536377 / current epochs : 0 / current sentence : 94408
# Loss at step 808000 : 5.3931355476379395 / current epochs : 0 / current sentence : 94508
# Loss at step 809000 : 5.422513484954834 / current epochs : 0 / current sentence : 94609
# Loss at step 810000 : 5.590766429901123 / current epochs : 0 / current sentence : 94733
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 811000 : 5.376794338226318 / current epochs : 0 / current sentence : 94856
# Loss at step 812000 : 5.18597412109375 / current epochs : 0 / current sentence : 94957
# Loss at step 813000 : 5.579836368560791 / current epochs : 0 / current sentence : 95069
# Loss at step 814000 : 5.47396993637085 / current epochs : 0 / current sentence : 95187
# Loss at step 815000 : 5.709108829498291 / current epochs : 0 / current sentence : 95300
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 816000 : 5.339465141296387 / current epochs : 0 / current sentence : 95411
# Loss at step 817000 : 5.467212677001953 / current epochs : 0 / current sentence : 95539
# Loss at step 818000 : 5.672266960144043 / current epochs : 0 / current sentence : 95658
# Loss at step 819000 : 5.548912525177002 / current epochs : 0 / current sentence : 95783
# Loss at step 820000 : 5.118913650512695 / current epochs : 0 / current sentence : 95894
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 821000 : 5.383923530578613 / current epochs : 0 / current sentence : 96018
# Loss at step 822000 : 5.401197910308838 / current epochs : 0 / current sentence : 96151
# Loss at step 823000 : 5.3626203536987305 / current epochs : 0 / current sentence : 96265
# Loss at step 824000 : 5.659450531005859 / current epochs : 0 / current sentence : 96389
# Loss at step 825000 : 5.592533111572266 / current epochs : 0 / current sentence : 96508
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 826000 : 5.044844150543213 / current epochs : 0 / current sentence : 96604
# Loss at step 827000 : 5.061738967895508 / current epochs : 0 / current sentence : 96708
# Loss at step 828000 : 5.593559741973877 / current epochs : 0 / current sentence : 96838
# Loss at step 829000 : 5.558775424957275 / current epochs : 0 / current sentence : 96965
# Loss at step 830000 : 5.090790271759033 / current epochs : 0 / current sentence : 97064
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 367/NNG, 10513/MM, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 831000 : 5.255950450897217 / current epochs : 0 / current sentence : 97164
# Loss at step 832000 : 5.551077842712402 / current epochs : 0 / current sentence : 97274
# Loss at step 833000 : 5.593141555786133 / current epochs : 0 / current sentence : 97394
# Loss at step 834000 : 5.427668571472168 / current epochs : 0 / current sentence : 97494
# Loss at step 835000 : 5.439056873321533 / current epochs : 0 / current sentence : 97630
# Nearest to 19517/NNG: 2828/NNG, 19389/NNG, 4127/NNG, 3292/NNP, 11190/NNG,
# Nearest to 9822/NNG: 8792/NNG, 2653/XR, 10513/MM, 367/NNG, 9179/NNG,
# Nearest to 1400/NNG: 4847/NNG, 7349/NNG, 1705/VV, 1408/NNG, 2740/NNG,
# Nearest to 16277/NNG: 11830/NNG, 30581/NNG, 5253/NNG, 19067/NNG, 1706/NNG,
# Model saved in file: E:\kakao\temp3\word2vec_embeddings.ckpt
# Loss at step 836000 : 5.591529369354248 / current epochs : 0 / current sentence : 97753
# Loss at step 837000 : 5.455806732177734 / current epochs : 0 / current sentence : 97886

# %%
embeddings

# %%
word_dictionary_rev[1]

# %%
embeddings[1]

# %%
gx = tf.matmul(normalized_embeddings, normalized_embeddings[1:2], transpose_b=True)

# %%
sess.run(gx)

# %%
tt = sorted(enumerate(sess.run(gx)), key=lambda x : x[1][0], reverse=True)

# %%
tt

# %%
word_dictionary_rev[184]

# %%
embeddings

# %%
vec = np.zeros(200)

# %%
text_data[0]

# %%
for i in text_data[0]:
    vec += embeddings[i]

# %%
vec

# %%
len(text_data[0])

# %%
allTexts = []

for c, t in enumerate(text_data) :
    vec = np.zeros(200)
    for i in t : 
        vec += em[i]
    allTexts.append(vec)
    
    if c% 100 == 0 : 
        print(c)

# %%
em = sess.run(embeddings)

# %%
em.shape

# %%
allTexts = np.array(allTexts)

# %%
from sklearn.preprocessing import normalize

# %%
allTexts = normalize(allTexts)

# %%
allTexts.shape

# %%
coss = np.dot(allTexts, allTexts[1].transpose())

# %%
tf = sorted(enumerate(coss), key = lambda x : x[1], reverse=True)

# %%
tf
