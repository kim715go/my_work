# %%
import pandas as pd

# %%
tripChain = pd.read_csv('PJT001_TripChain.csv')

# %%
tripChain.head()
# Out:
#      암호화카드번호||'  '||트랜잭션ID||'  '||환승횟수||'  '||교통카드발행사ID||'  '||총이용객수||'  \
# 0  900079696430            56           2          9000923            1
# 1  900079697651             5           1          9000923            1
# 2  900079698254            32           1          9000923            1
# 3  900079699257            80           1          9000923            1
# 4  900079701419            64           1          9000923            1
#
#    '||사용자구분||'  '||교통수단CD1||'  '||교통수단CD2||'  '||교통수단CD3||'  '||교통수단CD4||'  \
# 0            1          500.0          500.0            NaN            NaN
# 1            1          500.0            NaN            NaN            NaN
# 2            1          500.0            NaN            NaN            NaN
# 3            1          500.0            NaN            NaN            NaN
# 4            1          530.0            NaN            NaN            NaN
#
#    ...  '||하차역ID1||'  '||하차역ID2||'  '||하차역ID3||'  '||하차역ID4||'  '||하차역ID5||'  \
# ...

# %%
tripChain["암호화카드번호||'"].unique().shape
# Out:
# (498764,)

# %%
busRouteCode = pd.read_csv("PJT001_routestationmapping.csv")

# %%
busRouteCode.head()
# Out:
#      구분   운수사명    운수사ID     이비노선ID    표준노선ID    노선명
# 0  경기시내  경원여객M  2805000  216000044  28050900  M6410
# 1  경기시내   강화운수  4100100  232000028  41001001      2
# 2  경기시내   강화운수  4100100  232000029  41001013     88
# 3  경기시내   강화운수  4100100  232000061  41001020   3000
# 4  경기시내   강화운수  4100100  232000067  41001024    388

# %%
busRouteCode[busRouteCode['표준노선ID']==41031108]
# Out:
#         구분  운수사명    운수사ID     이비노선ID    표준노선ID  노선명
# 1458  경기시내  수원여객  4103100  200000045  41031108  7-1

# %%
tripChain[[x for x in tripChain.columns if "하차" in x]]
# Out:
#           '||하차일시1||'   '||하차일시2||'  '||하차일시3||'  '||하차일시4||'  '||하차일시5||'  \
# 0        2.018070e+13  2.018070e+13          NaN          NaN          NaN
# 1        2.018070e+13           NaN          NaN          NaN          NaN
# 2        2.018070e+13           NaN          NaN          NaN          NaN
# 3        2.018070e+13           NaN          NaN          NaN          NaN
# 4        2.018070e+13           NaN          NaN          NaN          NaN
# ...               ...           ...          ...          ...          ...
# 1048570  2.018070e+13           NaN          NaN          NaN          NaN
# 1048571  2.018070e+13           NaN          NaN          NaN          NaN
# 1048572  2.018070e+13  2.018070e+13          NaN          NaN          NaN
# 1048573  2.018070e+13           NaN          NaN          NaN          NaN
# 1048574  2.018070e+13           NaN          NaN          NaN          NaN
#
# ...

# %%
col = tripChain.columns.tolist()

# %%
col = [x.strip("|'") for x in col]

# %%
col
# Out:
# ['암호화카드번호',
#  '트랜잭션ID',
#  '환승횟수',
#  '교통카드발행사ID',
#  '총이용객수',
#  '사용자구분',
#  '교통수단CD1',
#  '교통수단CD2',
#  '교통수단CD3',
#  '교통수단CD4',
#  '교통수단CD5',
#  '버스노선ID1',
#  '버스노선ID2',
#  '버스노선ID3',
#  '버스노선ID4',
#  '버스노선ID5',
#  '차량ID1',
#  '차량ID2',
#  '차량ID3',
#  '차량ID4',
#  '차량ID5',
#  '총통행거리',
#  '총탑승시간',
#  '총소요시간',
#  '승차일시1',
#  '승차일시2',
#  '승차일시3',
#  '승차일시4',
#  '승차일시5',
#  '하차일시1',
#  '하차일시2',
#  '하차일시3',
#  '하차일시4',
#  '하차일시5',
#  '최초승차일시',
#  '최종하차일시',
#  '승차역ID1',
#  '승차역ID2',
#  '승차역ID3',
#  '승차역ID4',
#  '승차역ID5',
#  '하차역ID1',
#  '하차역ID2',
#  '하차역ID3',
#  '하차역ID4',
#  '하차역ID5',
#  '최초승차역ID',
#  '최종하차역ID',
#  '총이용금액',
#  '수집건수',
#  '트립체인완료코드']

# %%
tripChain.columns = col

# %%
tripChain.to_csv("tripChain.csv")

# %%
tripChain.head()
# Out:
#         암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  교통수단CD2  \
# 0  900079696430      56     2    9000923      1      1    500.0    500.0
# 1  900079697651       5     1    9000923      1      1    500.0      NaN
# 2  900079698254      32     1    9000923      1      1    500.0      NaN
# 3  900079699257      80     1    9000923      1      1    500.0      NaN
# 4  900079701419      64     1    9000923      1      1    530.0      NaN
#
#    교통수단CD3  교통수단CD4  ...  하차역ID1  하차역ID2  하차역ID3  하차역ID4  하차역ID5  최초승차역ID  \
# 0      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 1      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 2      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 3      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
# 4      NaN      NaN  ...     NaN     NaN     NaN     NaN     NaN      NaN
#
#      최종하차역ID  총이용금액  수집건수  트립체인완료코드
# 0  4116708.0   1350     2         ;
# ...

# %%
tripChain[['버스노선ID1', '총이용객수', '승차역ID1', '하차역ID1', '승차일시1', '하차일시1']]
# Out:
#             버스노선ID1     승차역ID1  하차역ID1         승차일시1         하차일시1
# 0        41002045.0  4116828.0     NaN  2.018070e+13  2.018070e+13
# 1        41031040.0  4117280.0     NaN  2.018070e+13  2.018070e+13
# 2        41031121.0  4199619.0     NaN  2.018070e+13  2.018070e+13
# 3        41031013.0  4108130.0     NaN  2.018070e+13  2.018070e+13
# 4        41020001.0  4100122.0     NaN  2.018070e+13  2.018070e+13
# ...             ...        ...     ...           ...           ...
# 1048570  41067012.0  4130419.0     NaN  2.018070e+13  2.018070e+13
# 1048571  41061025.0  4108112.0     NaN  2.018070e+13  2.018070e+13
# 1048572  41036131.0  4170340.0     NaN  2.018070e+13  2.018070e+13
# 1048573  41036113.0  4116734.0     NaN  2.018070e+13  2.018070e+13
# 1048574  41036113.0  4108147.0     NaN  2.018070e+13  2.018070e+13
#
# [1048575 rows x 5 columns]

# %%
tripChain['교통카드발행사ID'].unique()
# Out:
# array([9000923, 9000922, 9000931, 3101001, 9000901, 9000921, 9000929,
#        3101000, 3209345, 9000926, 9000930, 3101915, 3101916, 9000928,
#        3104000, 9000927, 3209905, 3104012, 3104201, 1000700, 3104011,
#        3101003, 3104015, 3101914, 3209755, 3104101, 3104103, 3101406,
#        3171107, 3209735, 3171119, 3101402, 3101408, 3171115, 3171110,
#        1000100, 3171117, 1000900, 3104013, 3104014, 3104104, 3104203,
#        3101900, 1000520, 1000800, 3104202, 3101401, 3107001, 3106000,
#        3106002, 3107000, 3171112, 3209825, 3171104, 3171100, 1000200,
#        1000500, 3101215, 3171109, 3171113, 3101409, 9000932, 3104002,
#        3171004, 3171116, 3209815], dtype=int64)

# %%
from collections import Counter

# %%
Counter(tripChain["총이용객수"])
# Out:
# Counter({1: 1034292, 2: 13473, 3: 698, 4: 85, 5: 14, 7: 4, 6: 6, 8: 2, 16: 1})

# %%
sample = pd.read_excel("sample.xlsx", index_col=0)

# %%
sample
# Out:
#           암호화카드번호||'  '||트랜잭션ID||'  '||환승횟수||'  '||교통카드발행사ID||'  '||총이용객수||'  \
# 16736   900029766098            69           1          3101915            1
# 16737   900029766098            70           1          3101915            1
# 185666  900029766098            71           1          3101915            1
# 185667  900029766098            74           2          3101915            1
# 185668  900029766098            76           1          3101915            1
# 185669  900029766098            77           2          3101915            1
# 630383  900029766098            78           1          3101915            1
# 630384  900029766098            79           3          3101915            1
# 630385  900029766098            80           3          3101915            1
# 630386  900029766098            81           1          3101915            1
# 630387  900029766098            82           1          3101915            1
# ...

# %%
sample.columns = col
newSample = sample[sample['환승횟수']==1]

# %%
newSample
# Out:
#              암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  교통수단CD2  \
# 16736   900029766098      69     1    3101915      1      1      500      NaN
# 16737   900029766098      70     1    3101915      1      1      500      NaN
# 185666  900029766098      71     1    3101915      1      1      500      NaN
# 185668  900029766098      76     1    3101915      1      1      500      NaN
# 630383  900029766098      78     1    3101915      1      1      500      NaN
# 630386  900029766098      81     1    3101915      1      1      500      NaN
# 630387  900029766098      82     1    3101915      1      1      500      NaN
# 630388  900029766098      83     1    3101915      1      1      500      NaN
# 630389  900029766098      84     1    3101915      1      1      500      NaN
# 980200  900029766098      85     1    3101915      1      1      500      NaN
# 980201  900029766098      86     1    3101915      1      1      500      NaN
# ...

# %%
others = sample[sample['환승횟수']!=1]

# %%
for i in others.iterrows():
    print(i[1]['환승횟수'])
# Out:
# 2
# 2
# 3
# 3

# %%
dupls = []
for i in others.iterrows() : 
    for j in range(i[1]['환승횟수']) : 
        dupls.append(i[1])

# %%
d = pd.DataFrame(dupls)

# %%
pd.concat([newSample, d])
# Out:
#              암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  교통수단CD2  \
# 16736   900029766098      69     1    3101915      1      1      500      NaN
# 16737   900029766098      70     1    3101915      1      1      500      NaN
# 185666  900029766098      71     1    3101915      1      1      500      NaN
# 185668  900029766098      76     1    3101915      1      1      500      NaN
# 630383  900029766098      78     1    3101915      1      1      500      NaN
# 630386  900029766098      81     1    3101915      1      1      500      NaN
# 630387  900029766098      82     1    3101915      1      1      500      NaN
# 630388  900029766098      83     1    3101915      1      1      500      NaN
# 630389  900029766098      84     1    3101915      1      1      500      NaN
# 980200  900029766098      85     1    3101915      1      1      500      NaN
# 980201  900029766098      86     1    3101915      1      1      500      NaN
# ...

# %%
newTripChain = tripChain[tripChain['총이용객수']==1]
otherTripChain = tripChain[tripChain['총이용객수']!=1]

# %%
otherTripChain
# Out:
#               암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  \
# 74       900517097760      73     1    9000926      2      1    500.0
# 112      900469281279      51     1    9000901      2      1    511.0
# 137      900508814234      81     1    9000922      2      1    500.0
# 221      900029950846      55     1    3101915      2      1    500.0
# 243      900168214800      98     1    9000923      2      1    500.0
# ...               ...     ...   ...        ...    ...    ...      ...
# 1048164  900199246876      54     1    9000929      2      1    500.0
# 1048260  900175634569      85     1    9000921      2      1    500.0
# 1048506  900465057125      89     1    9000923      2      4    500.0
# 1048553  900016596406      87     1    3101000      2      1    500.0
# 1048557  900016601791      70     1    3101000      2      1    500.0
#
#          교통수단CD2  교통수단CD3  교통수단CD4  ...  하차역ID1  하차역ID2  하차역ID3  하차역ID4  \
# ...

# %%
dupls = []
for i in otherTripChain.iterrows() : 
    for j in range(i[1]['총이용객수']) : 
        dupls.append(i[1])

# %%
d = pd.DataFrame(dupls)

# %%
d
# Out:
#               암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  \
# 74       900517097760      73     1    9000926      2      1    500.0
# 74       900517097760      73     1    9000926      2      1    500.0
# 112      900469281279      51     1    9000901      2      1    511.0
# 112      900469281279      51     1    9000901      2      1    511.0
# 137      900508814234      81     1    9000922      2      1    500.0
# ...               ...     ...   ...        ...    ...    ...      ...
# 1048506  900465057125      89     1    9000923      2      4    500.0
# 1048553  900016596406      87     1    3101000      2      1    500.0
# 1048553  900016596406      87     1    3101000      2      1    500.0
# 1048557  900016601791      70     1    3101000      2      1    500.0
# 1048557  900016601791      70     1    3101000      2      1    500.0
#
#          교통수단CD2  교통수단CD3  교통수단CD4  ...  하차역ID1  하차역ID2  하차역ID3  하차역ID4  \
# ...

# %%
newTripChain = pd.concat([newTripChain, d])

# %%
newTripChain
# Out:
#               암호화카드번호  트랜잭션ID  환승횟수  교통카드발행사ID  총이용객수  사용자구분  교통수단CD1  \
# 0        900079696430      56     2    9000923      1      1    500.0
# 1        900079697651       5     1    9000923      1      1    500.0
# 2        900079698254      32     1    9000923      1      1    500.0
# 3        900079699257      80     1    9000923      1      1    500.0
# 4        900079701419      64     1    9000923      1      1    530.0
# ...               ...     ...   ...        ...    ...    ...      ...
# 1048506  900465057125      89     1    9000923      2      4    500.0
# 1048553  900016596406      87     1    3101000      2      1    500.0
# 1048553  900016596406      87     1    3101000      2      1    500.0
# 1048557  900016601791      70     1    3101000      2      1    500.0
# 1048557  900016601791      70     1    3101000      2      1    500.0
#
#          교통수단CD2  교통수단CD3  교통수단CD4  ...  하차역ID1  하차역ID2  하차역ID3  하차역ID4  \
# ...

# %%
newTripChain = newTripChain.drop([x for x in col if "교통수단" in x], axis=1)

# %%
newTripChain = newTripChain.drop([x for x in col if "차량" in x], axis=1)

# %%
newTripChain = newTripChain.drop(['총이용객수', '트랜잭션ID', '사용자구분', '수집건수', '트립체인완료코드'], axis=1)

# %%
newTripChain = newTripChain.drop([x for x in col if "하차역" in x and "최종" not in x], axis=1)

# %%
newTripChain
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1     버스노선ID2  버스노선ID3  \
# 0        900079696430     2    9000923  41002045.0  41002044.0      NaN
# 1        900079697651     1    9000923  41031040.0         NaN      NaN
# 2        900079698254     1    9000923  41031121.0         NaN      NaN
# 3        900079699257     1    9000923  41031013.0         NaN      NaN
# 4        900079701419     1    9000923  41020001.0         NaN      NaN
# ...               ...   ...        ...         ...         ...      ...
# 1048506  900465057125     1    9000923  41031020.0         NaN      NaN
# 1048553  900016596406     1    3101000  41002090.0         NaN      NaN
# 1048553  900016596406     1    3101000  41002090.0         NaN      NaN
# 1048557  900016601791     1    3101000  41067012.0         NaN      NaN
# 1048557  900016601791     1    3101000  41067012.0         NaN      NaN
#
#          버스노선ID4  버스노선ID5  총통행거리  총탑승시간  ...          최초승차일시           최종하차일시  \
# ...

# %%
newTripChain.to_csv("tripChain.csv")

# %%
newTripChain.dropna('최종하차일시')
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1  버스노선ID2  버스노선ID3  버스노선ID4  \
# 178      900497300066     1    9000923  41036108.0      NaN      NaN      NaN
# 329      900477145143     1    9000923  41002046.0      NaN      NaN      NaN
# 341      900520400816     1    9000901  41031020.0      NaN      NaN      NaN
# 352      900520402372     1    3101916  41074061.0      NaN      NaN      NaN
# 419      900029248760     1    3101915  41031046.0      NaN      NaN      NaN
# ...               ...   ...        ...         ...      ...      ...      ...
# 1042146  900515150872     1    3101001  41036115.0      NaN      NaN      NaN
# 1042146  900515150872     1    3101001  41036115.0      NaN      NaN      NaN
# 1043136  100068114562     1    3104012  41075033.0      NaN      NaN      NaN
# 1043136  100068114562     1    3104012  41075033.0      NaN      NaN      NaN
# 1043136  100068114562     1    3104012  41075033.0      NaN      NaN      NaN
#
# ...

# %%
singleTrip = newTripChain[newTripChain['환승횟수'] == 1]

# %%
singleTrip.shape
# Out:
# (626656, 31)

# %%
singleTrip
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1  버스노선ID2  버스노선ID3  버스노선ID4  \
# 1        900079697651     1    9000923  41031040.0      NaN      NaN      NaN
# 2        900079698254     1    9000923  41031121.0      NaN      NaN      NaN
# 3        900079699257     1    9000923  41031013.0      NaN      NaN      NaN
# 4        900079701419     1    9000923  41020001.0      NaN      NaN      NaN
# 5        900079701419     1    9000923  41020001.0      NaN      NaN      NaN
# ...               ...   ...        ...         ...      ...      ...      ...
# 1048506  900465057125     1    9000923  41031020.0      NaN      NaN      NaN
# 1048553  900016596406     1    3101000  41002090.0      NaN      NaN      NaN
# 1048553  900016596406     1    3101000  41002090.0      NaN      NaN      NaN
# 1048557  900016601791     1    3101000  41067012.0      NaN      NaN      NaN
# 1048557  900016601791     1    3101000  41067012.0      NaN      NaN      NaN
#
# ...

# %%
abnormal = singleTrip[singleTrip['버스노선ID1'].isna()]
normal = singleTrip.dropna(subset=['버스노선ID1'])

# %%
normal[normal['최종하차역ID'].isna()]['최종하차일시']
# Out:
# 178        _
# 329        _
# 341        _
# 352        _
# 419        _
#           ..
# 1042146    _
# 1042146    _
# 1043136    _
# 1043136    _
# 1043136    _
# Name: 최종하차일시, Length: 12084, dtype: object

# %%
singleTrip = singleTrip.drop(['버스노선ID2',
 '버스노선ID3',
 '버스노선ID4',
 '버스노선ID5'], axis=1)

# %%
singleTrip
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1  총통행거리  총탑승시간  총소요시간  \
# 1        900079697651     1    9000923  41031040.0   1700      3      3
# 2        900079698254     1    9000923  41031121.0  23180     66     66
# 3        900079699257     1    9000923  41031013.0    500      1      1
# 4        900079701419     1    9000923  41020001.0   3240      8      8
# 5        900079701419     1    9000923  41020001.0   2940      8      8
# ...               ...   ...        ...         ...    ...    ...    ...
# 1048506  900465057125     1    9000923  41031020.0   1210      4      4
# 1048553  900016596406     1    3101000  41002090.0    950      3      3
# 1048553  900016596406     1    3101000  41002090.0    950      3      3
# 1048557  900016601791     1    3101000  41067012.0   4660     19     19
# 1048557  900016601791     1    3101000  41067012.0   4660     19     19
#
#                 승차일시1  승차일시2  승차일시3  ...          최초승차일시           최종하차일시  \
# ...

# %%
singleTrip = singleTrip.drop(['승차역ID2',
 '승차역ID3',
 '승차역ID4',
 '승차역ID5','최초승차역ID'], axis=1)

# %%
singleTrip
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1  총통행거리  총탑승시간  총소요시간  \
# 1        900079697651     1    9000923  41031040.0   1700      3      3
# 2        900079698254     1    9000923  41031121.0  23180     66     66
# 3        900079699257     1    9000923  41031013.0    500      1      1
# 4        900079701419     1    9000923  41020001.0   3240      8      8
# 5        900079701419     1    9000923  41020001.0   2940      8      8
# ...               ...   ...        ...         ...    ...    ...    ...
# 1048506  900465057125     1    9000923  41031020.0   1210      4      4
# 1048553  900016596406     1    3101000  41002090.0    950      3      3
# 1048553  900016596406     1    3101000  41002090.0    950      3      3
# 1048557  900016601791     1    3101000  41067012.0   4660     19     19
# 1048557  900016601791     1    3101000  41067012.0   4660     19     19
#
#                 승차일시1  승차일시2  승차일시3  ...         하차일시1  하차일시2  하차일시3  하차일시4  \
# ...

# %%
singleTrip[singleTrip['승차일시1'] != singleTrip['최초승차일시']]
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID  버스노선ID1  총통행거리  총탑승시간  총소요시간  승차일시1  \
# 203121   900024806872     1    3101000      NaN   1060      4      4    NaN
# 286955   900393917394     1    3101000      NaN      0      0      0    NaN
# 314172   900524109274     1    3209905      NaN   4220     19     19    NaN
# 346262   900131350297     1    9000901      NaN      0      0      0    NaN
# 518936   900388341884     1    3101001      NaN   2340      8      8    NaN
# 558464   900018098221     1    3101000      NaN   1910      7      7    NaN
# 571908   900111495390     1    9000901      NaN   6930     17     17    NaN
# 611988   900084722814     1    9000923      NaN      0      0      0    NaN
# 611989   900084722814     1    9000923      NaN      0      0      0    NaN
# 612618   900478094602     1    9000929      NaN   3270     16     16    NaN
# 615950   900023194967     1    3101000      NaN      0      2      2    NaN
# ...

# %%
singleTrip[singleTrip['최종하차역ID'].isna()]
# Out:
#               암호화카드번호  환승횟수  교통카드발행사ID     버스노선ID1  총통행거리  총탑승시간  총소요시간  \
# 178      900497300066     1    9000923  41036108.0      0      0      0
# 329      900477145143     1    9000923  41002046.0      0      0      0
# 341      900520400816     1    9000901  41031020.0      0      0      0
# 352      900520402372     1    3101916  41074061.0      0      0      0
# 419      900029248760     1    3101915  41031046.0      0      0      0
# ...               ...   ...        ...         ...    ...    ...    ...
# 1042146  900515150872     1    3101001  41036115.0      0      0      0
# 1042146  900515150872     1    3101001  41036115.0      0      0      0
# 1043136  100068114562     1    3104012  41075033.0      0      0      0
# 1043136  100068114562     1    3104012  41075033.0      0      0      0
# 1043136  100068114562     1    3104012  41075033.0      0      0      0
#
#                 승차일시1  승차일시2  승차일시3  ...  하차일시1  하차일시2  하차일시3  하차일시4  하차일시5  \
# ...

# %%
# Out:
# 1048575
